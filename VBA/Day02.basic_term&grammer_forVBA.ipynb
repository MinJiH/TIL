# %% [markdown]
# # Basic term of VBA and interface

# %% [markdown]
# sub procedure : defining the macro
# vba is consist of sub, end
# and if want to make the function, you have to make "function procedure"
# starting "function " ending with "end function".
#
# in case of making the object, starting with "property" ending with ""
#
# there are imperative sentence -1)선언문 2)실행문 whichi is consist of procedures.
# implementing 선언문, 실행문 object should be in need.
# group of object is called as "collection"
# ![image.png](attachment:image.png)

# %% [markdown]
# # basic grammer for VBA
# -연산자(두개의 자료형에 대해 어떤일 을 하고 싶은지 결정하는 -eg) 사칙연산, 옳고 그름 판단)
# -변수
# -자료형
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# # basic grammer for VBA & rules for coding (practice of 연산자)
