# %%
import sqlite3 as lite
import pandas as pd
#what pandas is the package python have provided including numpy. 
#what pandad does is providing a various function  which makes the frame of data

# %%
db=lite.connect("./products.db")
#connecting the data from sql to pandas which is python
# throguth the command of connect, the DB file will be made. in that case, the sqlite_master which is the mas
#ter db table will be made. in that table all the data will be saved, no edit only read.

# %%
query= "SELECT * FROM customers;"
#make cursor
cur =db.cursor()
#send query to cursor
cur.execute(query)
#fetch results
cur.fetchall()[0]
# Out:
# ('1',
#  'Alfreds Futterkiste',
#  'Maria Anders',
#  'Obere Str. 57',
#  'Berlin',
#  '12209',
#  'Germany')

# %%
#making the function of reading the sql through pandas
df =pd.read_sql(query,db)
df.head()
# Out:
#   CustomerID                        CustomerName         ContactName  \
# 0          1                 Alfreds Futterkiste        Maria Anders
# 1          2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2          3             Antonio Moreno Taquería      Antonio Moreno
# 3          4                     Around the Horn        Thomas Hardy
# 4          5                  Berglunds snabbköp  Christina Berglund
#
#                          Address         City PostalCode  Country
# 0                  Obere Str. 57       Berlin      12209  Germany
# 1  Avda. de la Constitución 2222  México D.F.      05021   Mexico
# 2                 Mataderos 2312  México D.F.      05023   Mexico
# 3                120 Hanover Sq.       London    WA1 1DP       UK
# 4                 Berguvsvägen 8        Luleå   S-958 22   Sweden

# %%
query="""
SELECT *
    FROM sqlite_master
"""
pd.read_sql(query,db)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table    Categories    Categories         2
# 1  table     Customers     Customers         3
# 2  table     Employees     Employees         6
# 3  table      Shippers      Shippers        15
# 4  table     Suppliers     Suppliers        16
# 5  table        Orders        Orders        11
# 6  table  OrderDetails  OrderDetails         7
# 7  table      Products      Products        14
# 8  table    assignment    assignment         8
#
#                                                                                                                                                                                            sql
# 0                                                                                              CREATE TABLE Categories(\n  "CategoryID" TEXT,\n  "CategoryName" TEXT,\n  "Description" TEXT\n)
# ...

# %%
pd.options.display.max_colwidth = 300

# %%
query="""
SELECT tbl_name
    FROM sqlite_master
    ;


"""
pd.read_sql(query,db)
# Out:
#        tbl_name
# 0    Categories
# 1     Customers
# 2     Employees
# 3      Shippers
# 4     Suppliers
# 5        Orders
# 6  OrderDetails
# 7      Products
# 8    assignment

# %%
query="""
SELECT sql
    FROM sqlite_master

"""
pd.read_sql(query,db)
# Out:
#                                                                                                                                                                                            sql
# 0                                                                                              CREATE TABLE Categories(\n  "CategoryID" TEXT,\n  "CategoryName" TEXT,\n  "Description" TEXT\n)
# 1                   CREATE TABLE Customers(\n  "CustomerID" TEXT,\n  "CustomerName" TEXT,\n  "ContactName" TEXT,\n  "Address" TEXT,\n  "City" TEXT,\n  "PostalCode" TEXT,\n  "Country" TEXT\n)
# 2                                              CREATE TABLE Employees(\n  "EmployeeID" TEXT,\n  "LastName" TEXT,\n  "FirstName" TEXT,\n  "BirthDate" TEXT,\n  "Photo" TEXT,\n  "Notes" TEXT\n)
# 3                                                                                                        CREATE TABLE Shippers(\n  "ShipperID" TEXT,\n  "ShipperName" TEXT,\n  "Phone" TEXT\n)
# ...

# %%
query="""
SELECT *
    FROM Customers

"""
df=pd.read_sql(query,db)

# %%
fran=df["County"]=="France"
germ=df["Country"]=="Germany"
df[fran|germ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-bacb21c7a6ec> in <module>
# ----> 1 fran=df["County"]=="France"
# ...

# %%
query="""
SELECT *
FROM Customers
WHERE
    Country IN ("Germany","France")

"""
pd.read_sql(query,db)
# Out:
#    CustomerID               CustomerName          ContactName  \
# 0           1        Alfreds Futterkiste         Maria Anders
# 1           6    Blauer See Delikatessen           Hanna Moos
# 2           7       Blondel père et fils   Frédérique Citeaux
# 3           9                   Bon app'    Laurence Lebihans
# 4          17  Drachenblut Delikatessend         Sven Ottlieb
# 5          18            Du monde entier       Janine Labrune
# 6          23          Folies gourmandes        Martine Rancé
# 7          25             Frankenversand        Peter Franken
# 8          26        France restauration       Carine Schmitt
# 9          39            Königlich Essen        Philip Cramer
# 10         40       La corne d'abondance        Daniel Tonini
# 11         41           La maison d'Asie       Annette Roulet
# 12         44        Lehmanns Marktstand       Renate Messner
# 13         52     Morgenstern Gesundkost      Alexander Feuer
# ...

# %%
query ="""
SELECT *
FROM Customers
;

"""
df=pd.read_sql(query,db)

# %%
df[(df["County"]=="Germany")|(df["City"]=="Paris")]
#"""
#SELCT *
#FROM Customers
#WHERE
   # County =="Germany" 
   # CITY == "Paris";
#"""
df[(df["Country"]=="Germany")&(df["City"]=="Paris")]
#"""
#SELECT *
#FROM Customers
#WHERE
    #Country == "Germany"
    #AND
    #CITY == "Paris"
    #;
#"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'County'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-a644d0121760> in <module>
# ...
